# %% [markdown]
# # MLP for the Proposal Video

# %% [markdown]
# ## Improvement Ideas
#  - Penalize false positives more heavily using the Loss
#  - Create bigger Dataset
#  - Include the algorithms introduced in the Paper
#  - Possibly change to CNN
#
# ## Current Problems
#  - To many ill as healthy classified, especcialy early blight
#  - To confident in wrong predictions

# %% [markdown]
# ## 1. Import the required libraries

# %%
# !pip install torchsummary
# !pip install kagglehub

import os
import time
import zipfile
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Rectangle
from matplotlib import transforms as mtransforms

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import models, datasets, transforms
from torchsummary import summary
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import kagglehub
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (1.5.1)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (0.3.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kagglehub) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub) (4.66.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (2024.8.30)

# %% [markdown]
# ## 2. Set model parameters

# %%
num_classes = 3

# Define the batch size (16 or 32 reccomended)
batch_size = 16

# Define the size the images get resized to (64 reccomended)
image_size = 224

# Number of epochs the trainig runs (150 reccomended)
number_of_epochs = 1000

# Number of epochs without improvement of loss till the training get terminated early (20 reccomended)
early_stop_patience = 20

# If the dataset should be taken from the zip file (false reccomended (then the dataset gets downloaded))
dataset_as_zip = False

# Path of the zip file (only needed if dataset_as_zip = True)
zip_path = "../data/potato_blight.zip"

# Path where the best model should be saved to
best_model_path = '../content/best_model/best_model.pth'
if not os.path.exists(os.path.dirname(best_model_path)):
    os.makedirs(os.path.dirname(best_model_path))

# %% [markdown]
# ## 3. Get the dataset

# %% [markdown]
# ### 3.1 Import the dataset

# %%
if not dataset_as_zip:

    path = kagglehub.dataset_download("muhammadardiputra/potato-leaf-disease-dataset")

else:

    if not os.path.exists(zip_path):
        raise FileNotFoundError(f"The data expected at '{zip_path}' was not found.")

    path = "../.extracted_data"

    if not os.path.exists(path):
        os.makedirs(path)

    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(path)

train_data_path = os.path.join(path + "/Potato", "Train")
test_data_path = os.path.join(path + "/Potato", "Test")
valid_data_path = os.path.join(path + "/Potato", "Valid")
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/muhammadardiputra/potato-leaf-disease-dataset?dataset_version_number=1...
# 100%|██████████| 25.2M/25.2M [00:00<00:00, 38.1MB/s]
# Extracting files...

# %% [markdown]
# ### 3.2 Transform and argument the dataset

# %%
train_transform = transforms.Compose([
    transforms.RandomApply([transforms.Grayscale(num_output_channels=3)], p=0.5),
    transforms.Resize((image_size, image_size)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(root=train_data_path, transform=train_transform)
val_dataset = datasets.ImageFolder(root=valid_data_path, transform=val_transform)

# %% [markdown]
# ### 3.3 Load the data into batches

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

for batch_idx, (data, target) in enumerate(train_loader):
    print(f'Batch {batch_idx + 1}:')
    print('Data shape:', data.shape)
    print('Target shape:', target.shape)

mean_image = torch.mean(torch.cat([data for data, _ in train_loader], dim=0), dim=0).numpy()

print('Mean image shape:', mean_image.shape)
# Out:
# Batch 1:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 2:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 3:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 4:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 5:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 6:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 7:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 8:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 9:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 10:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 11:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 12:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 13:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 14:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 15:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 16:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 17:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 18:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 19:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 20:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 21:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 22:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 23:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 24:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 25:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 26:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 27:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 28:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 29:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 30:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 31:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 32:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 33:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 34:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 35:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 36:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 37:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 38:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 39:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 40:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 41:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 42:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 43:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 44:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 45:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 46:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 47:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 48:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 49:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 50:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 51:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 52:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 53:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 54:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 55:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 56:
# Data shape: torch.Size([16, 3, 224, 224])
# Target shape: torch.Size([16])
# Batch 57:
# Data shape: torch.Size([4, 3, 224, 224])
# Target shape: torch.Size([4])
# Mean image shape: (3, 224, 224)

# %% [markdown]
# ## 4. Define AlexNet for feature extraction
# (we will only use the feature extraction part of the model)

# %%
alexnet = models.alexnet(pretrained=True)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('Device:', device)
alexnet.to(device)

num_params = sum(p.numel() for p in alexnet.parameters() if p.requires_grad)
print("Number of trainable parameters:", num_params)

summary(alexnet, (3, image_size, image_size))
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:03<00:00, 71.4MB/s]
# Device: cpu
# Number of trainable parameters: 61100840
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 55, 55]          23,296
#               ReLU-2           [-1, 64, 55, 55]               0
#          MaxPool2d-3           [-1, 64, 27, 27]               0
#             Conv2d-4          [-1, 192, 27, 27]         307,392
#               ReLU-5          [-1, 192, 27, 27]               0
#          MaxPool2d-6          [-1, 192, 13, 13]               0
#             Conv2d-7          [-1, 384, 13, 13]         663,936
#               ReLU-8          [-1, 384, 13, 13]               0
#             Conv2d-9          [-1, 256, 13, 13]         884,992
#              ReLU-10          [-1, 256, 13, 13]               0
#            Conv2d-11          [-1, 256, 13, 13]         590,080
#              ReLU-12          [-1, 256, 13, 13]               0
#         MaxPool2d-13            [-1, 256, 6, 6]               0
# AdaptiveAvgPool2d-14            [-1, 256, 6, 6]               0
#           Dropout-15                 [-1, 9216]               0
#            Linear-16                 [-1, 4096]      37,752,832
#              ReLU-17                 [-1, 4096]               0
#           Dropout-18                 [-1, 4096]               0
#            Linear-19                 [-1, 4096]      16,781,312
#              ReLU-20                 [-1, 4096]               0
#            Linear-21                 [-1, 1000]       4,097,000
# ================================================================
# Total params: 61,100,840
# Trainable params: 61,100,840
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 8.38
# Params size (MB): 233.08
# Estimated Total Size (MB): 242.03
# ----------------------------------------------------------------

# %%
def extract_features(model, dataloader, device):
    model.eval()
    features = []
    labels = []
    with torch.no_grad():
        for data, target in dataloader:
            data, target = data.to(device), target.to(device)
            output = model.features(data)
            features.append(output.view(output.size(0), -1).cpu().numpy())
            labels.append(target.cpu().numpy())
    return np.vstack(features), np.hstack(labels)

# %% [markdown]
# ##5. WWPASC implementation

# %%
def fitness_function(features, labels, selected_features):
    if np.sum(selected_features) == 0:
        return 0
    selected_data = features[:, selected_features == 1]
    X_train, X_val, y_train, y_val = train_test_split(selected_data, labels, test_size=0.2, random_state=42)
    classifier = nn.Sequential(
        nn.Linear(selected_data.shape[1], 100),
        nn.ReLU(),
        nn.Linear(100, num_classes),
    ).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(classifier.parameters(), lr=0.0005)

    for epoch in range(5):
        classifier.train()
        optimizer.zero_grad()
        outputs = classifier(torch.tensor(X_train, dtype=torch.float32).to(device))
        loss = criterion(outputs, torch.tensor(y_train, dtype=torch.long).to(device))
        loss.backward()
        optimizer.step()

    classifier.eval()
    outputs = classifier(torch.tensor(X_val, dtype=torch.float32).to(device))
    predictions = torch.argmax(outputs, dim=1).cpu().numpy()
    return accuracy_score(y_val, predictions)


def wwpasc(features, labels, population_size=10, max_iterations=20):
    num_features = features.shape[1]
    population = np.random.randint(2, size=(population_size, num_features))
    best_solution = None
    best_fitness = -1

    for iteration in range(max_iterations):
        fitness_scores = np.array([fitness_function(features, labels, individual) for individual in population])
        sorted_indices = np.argsort(fitness_scores)[::-1]
        population = population[sorted_indices]

        # Update best solution
        if fitness_scores[0] > best_fitness:
            best_fitness = fitness_scores[0]
            best_solution = population[0].copy()

        # Update population
        for i in range(1, population_size):
            random_factor = np.random.uniform()
            if random_factor > 0.7:
                population[i] = best_solution
            else:
                population[i] = np.random.randint(2, size=num_features)

    return best_solution

# %% [markdown]
# ## 6. Train the model

# %% [markdown]
# ### 6.1 Define and run the training

# %%
# Extract and select features
features, labels = extract_features(alexnet, train_loader, device)
best_features = wwpasc(features, labels, population_size=20, max_iterations=50)


# Train final model with selected features
selected_features = features[:, best_features == 1]
X_train, X_val, y_train, y_val = train_test_split(selected_features, labels, test_size=0.2, random_state=42)

print(f"Selected features shape: {selected_features.shape}")

input_size = selected_features.shape[1]
final_model = nn.Sequential(
    nn.Linear(input_size, 256),
    nn.ReLU(),
    nn.Dropout(0.3),
    nn.Linear(256, 128),
    nn.ReLU(),
    nn.Linear(128, num_classes),
).to(device)



criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(final_model.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, min_lr=1e-6)


early_stop_counter = 0
best_val_loss = float('inf')
history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

print(f"Selected features shape: {selected_features.shape}")


# Training loop
for epoch in range(number_of_epochs):
    final_model.train()
    optimizer.zero_grad()
    outputs = final_model(torch.tensor(X_train, dtype=torch.float32).to(device))
    loss = criterion(outputs, torch.tensor(y_train, dtype=torch.long).to(device))
    loss.backward()
    optimizer.step()

    _, predicted = torch.max(outputs, 1)
    train_acc = (predicted.cpu().numpy() == y_train).sum() / len(y_train)
    history['train_loss'].append(loss.item())
    history['train_acc'].append(train_acc)

    # Validation
    final_model.eval()
    with torch.no_grad():
        outputs_val = final_model(torch.tensor(X_val, dtype=torch.float32).to(device))
        val_loss = criterion(outputs_val, torch.tensor(y_val, dtype=torch.long).to(device))

        _, predicted_val = torch.max(outputs_val, 1)
        val_acc = (predicted_val.cpu().numpy() == y_val).sum() / len(y_val)
        history['val_loss'].append(val_loss.item())
        history['val_acc'].append(val_acc)

    print(f"[Epoch {epoch + 1}] Train Loss: {loss.item():.5f}, Train Acc: {train_acc:.4f}, "
          f"Val Loss: {val_loss.item():.5f}, Val Acc: {val_acc:.4f}")

    scheduler.step(val_loss.item())

    if val_loss.item() < best_val_loss:
        best_val_loss = val_loss.item()
        best_model_state = final_model.state_dict()
        early_stop_counter = 0
        print(f"Saved best model at epoch {epoch + 1}")
    else:
        early_stop_counter += 1
        if early_stop_counter >= early_stop_patience:
            print(f"Early stopping at epoch {epoch + 1}")
            break

# Save the final model
torch.save(best_model_state, best_model_path)
print(f"Final model saved with validation loss: {best_val_loss:.5f}")
# Out:
# Selected features shape: (900, 4585)
# Selected features shape: (900, 4585)
# [Epoch 1] Train Loss: 1.12372, Train Acc: 0.3194, Val Loss: 1.14098, Val Acc: 0.3944
# Saved best model at epoch 1
# [Epoch 2] Train Loss: 1.07749, Train Acc: 0.4917, Val Loss: 0.84609, Val Acc: 0.5444
# Saved best model at epoch 2
# [Epoch 3] Train Loss: 0.82692, Train Acc: 0.5500, Val Loss: 0.69730, Val Acc: 0.6111
# Saved best model at epoch 3
# [Epoch 4] Train Loss: 0.68052, Train Acc: 0.6542, Val Loss: 0.53742, Val Acc: 0.7778
# Saved best model at epoch 4
# [Epoch 5] Train Loss: 0.49425, Train Acc: 0.8028, Val Loss: 0.52061, Val Acc: 0.7167
# Saved best model at epoch 5
# [Epoch 6] Train Loss: 0.47346, Train Acc: 0.7722, Val Loss: 0.34933, Val Acc: 0.8944
# Saved best model at epoch 6
# [Epoch 7] Train Loss: 0.34159, Train Acc: 0.8861, Val Loss: 0.32214, Val Acc: 0.9111
# Saved best model at epoch 7
# [Epoch 8] Train Loss: 0.31574, Train Acc: 0.8931, Val Loss: 0.28444, Val Acc: 0.9222
# Saved best model at epoch 8
# [Epoch 9] Train Loss: 0.27361, Train Acc: 0.8889, Val Loss: 0.22183, Val Acc: 0.9222
# Saved best model at epoch 9
# [Epoch 10] Train Loss: 0.21397, Train Acc: 0.9333, Val Loss: 0.22008, Val Acc: 0.9056
# Saved best model at epoch 10
# [Epoch 11] Train Loss: 0.19659, Train Acc: 0.9292, Val Loss: 0.19236, Val Acc: 0.9444
# Saved best model at epoch 11
# [Epoch 12] Train Loss: 0.17912, Train Acc: 0.9389, Val Loss: 0.14051, Val Acc: 0.9556
# Saved best model at epoch 12
# [Epoch 13] Train Loss: 0.14451, Train Acc: 0.9500, Val Loss: 0.12728, Val Acc: 0.9611
# Saved best model at epoch 13
# [Epoch 14] Train Loss: 0.12180, Train Acc: 0.9611, Val Loss: 0.13621, Val Acc: 0.9500
# [Epoch 15] Train Loss: 0.10931, Train Acc: 0.9708, Val Loss: 0.11505, Val Acc: 0.9667
# Saved best model at epoch 15
# [Epoch 16] Train Loss: 0.07981, Train Acc: 0.9708, Val Loss: 0.08901, Val Acc: 0.9722
# Saved best model at epoch 16
# [Epoch 17] Train Loss: 0.07688, Train Acc: 0.9736, Val Loss: 0.08302, Val Acc: 0.9722
# Saved best model at epoch 17
# [Epoch 18] Train Loss: 0.05703, Train Acc: 0.9861, Val Loss: 0.08719, Val Acc: 0.9722
# [Epoch 19] Train Loss: 0.05525, Train Acc: 0.9847, Val Loss: 0.08316, Val Acc: 0.9722
# [Epoch 20] Train Loss: 0.04681, Train Acc: 0.9903, Val Loss: 0.06990, Val Acc: 0.9722
# Saved best model at epoch 20
# [Epoch 21] Train Loss: 0.03166, Train Acc: 0.9917, Val Loss: 0.06168, Val Acc: 0.9778
# Saved best model at epoch 21
# [Epoch 22] Train Loss: 0.02950, Train Acc: 0.9903, Val Loss: 0.06571, Val Acc: 0.9722
# [Epoch 23] Train Loss: 0.02427, Train Acc: 0.9958, Val Loss: 0.07310, Val Acc: 0.9667
# [Epoch 24] Train Loss: 0.02256, Train Acc: 0.9958, Val Loss: 0.06927, Val Acc: 0.9667
# [Epoch 25] Train Loss: 0.01815, Train Acc: 0.9986, Val Loss: 0.05824, Val Acc: 0.9722
# Saved best model at epoch 25
# [Epoch 26] Train Loss: 0.01378, Train Acc: 0.9986, Val Loss: 0.04943, Val Acc: 0.9889
# Saved best model at epoch 26
# [Epoch 27] Train Loss: 0.00944, Train Acc: 0.9986, Val Loss: 0.04937, Val Acc: 0.9778
# Saved best model at epoch 27
# [Epoch 28] Train Loss: 0.00826, Train Acc: 1.0000, Val Loss: 0.05472, Val Acc: 0.9722
# [Epoch 29] Train Loss: 0.00801, Train Acc: 1.0000, Val Loss: 0.06176, Val Acc: 0.9722
# [Epoch 30] Train Loss: 0.01035, Train Acc: 0.9986, Val Loss: 0.06822, Val Acc: 0.9722
# [Epoch 31] Train Loss: 0.00757, Train Acc: 1.0000, Val Loss: 0.06917, Val Acc: 0.9722
# [Epoch 32] Train Loss: 0.00706, Train Acc: 0.9986, Val Loss: 0.06467, Val Acc: 0.9722
# [Epoch 33] Train Loss: 0.00621, Train Acc: 0.9986, Val Loss: 0.05785, Val Acc: 0.9722
# [Epoch 34] Train Loss: 0.00344, Train Acc: 1.0000, Val Loss: 0.05470, Val Acc: 0.9722
# [Epoch 35] Train Loss: 0.00379, Train Acc: 1.0000, Val Loss: 0.05119, Val Acc: 0.9722
# [Epoch 36] Train Loss: 0.00335, Train Acc: 1.0000, Val Loss: 0.04809, Val Acc: 0.9778
# Saved best model at epoch 36
# [Epoch 37] Train Loss: 0.00369, Train Acc: 1.0000, Val Loss: 0.04568, Val Acc: 0.9778
# Saved best model at epoch 37
# [Epoch 38] Train Loss: 0.00183, Train Acc: 1.0000, Val Loss: 0.04408, Val Acc: 0.9778
# Saved best model at epoch 38
# [Epoch 39] Train Loss: 0.00242, Train Acc: 1.0000, Val Loss: 0.04310, Val Acc: 0.9833
# Saved best model at epoch 39
# [Epoch 40] Train Loss: 0.00257, Train Acc: 1.0000, Val Loss: 0.04235, Val Acc: 0.9889
# Saved best model at epoch 40
# [Epoch 41] Train Loss: 0.00212, Train Acc: 1.0000, Val Loss: 0.04207, Val Acc: 0.9889
# Saved best model at epoch 41
# [Epoch 42] Train Loss: 0.00262, Train Acc: 1.0000, Val Loss: 0.04215, Val Acc: 0.9889
# [Epoch 43] Train Loss: 0.00162, Train Acc: 1.0000, Val Loss: 0.04242, Val Acc: 0.9889
# [Epoch 44] Train Loss: 0.00230, Train Acc: 1.0000, Val Loss: 0.04266, Val Acc: 0.9889
# [Epoch 45] Train Loss: 0.00213, Train Acc: 1.0000, Val Loss: 0.04280, Val Acc: 0.9778
# [Epoch 46] Train Loss: 0.00198, Train Acc: 1.0000, Val Loss: 0.04286, Val Acc: 0.9778
# [Epoch 47] Train Loss: 0.00156, Train Acc: 1.0000, Val Loss: 0.04269, Val Acc: 0.9833
# [Epoch 48] Train Loss: 0.00239, Train Acc: 1.0000, Val Loss: 0.04252, Val Acc: 0.9889
# [Epoch 49] Train Loss: 0.00213, Train Acc: 1.0000, Val Loss: 0.04222, Val Acc: 0.9889
# [Epoch 50] Train Loss: 0.00120, Train Acc: 1.0000, Val Loss: 0.04191, Val Acc: 0.9889
# Saved best model at epoch 50
# [Epoch 51] Train Loss: 0.00337, Train Acc: 0.9986, Val Loss: 0.04159, Val Acc: 0.9889
# Saved best model at epoch 51
# [Epoch 52] Train Loss: 0.00097, Train Acc: 1.0000, Val Loss: 0.04132, Val Acc: 0.9889
# Saved best model at epoch 52
# [Epoch 53] Train Loss: 0.00120, Train Acc: 1.0000, Val Loss: 0.04109, Val Acc: 0.9889
# Saved best model at epoch 53
# [Epoch 54] Train Loss: 0.00133, Train Acc: 1.0000, Val Loss: 0.04084, Val Acc: 0.9889
# Saved best model at epoch 54
# [Epoch 55] Train Loss: 0.00097, Train Acc: 1.0000, Val Loss: 0.04068, Val Acc: 0.9889
# Saved best model at epoch 55
# [Epoch 56] Train Loss: 0.00166, Train Acc: 1.0000, Val Loss: 0.04054, Val Acc: 0.9889
# Saved best model at epoch 56
# [Epoch 57] Train Loss: 0.00117, Train Acc: 1.0000, Val Loss: 0.04052, Val Acc: 0.9889
# Saved best model at epoch 57
# [Epoch 58] Train Loss: 0.00138, Train Acc: 1.0000, Val Loss: 0.04065, Val Acc: 0.9833
# [Epoch 59] Train Loss: 0.00136, Train Acc: 1.0000, Val Loss: 0.04089, Val Acc: 0.9833
# [Epoch 60] Train Loss: 0.00131, Train Acc: 1.0000, Val Loss: 0.04121, Val Acc: 0.9833
# [Epoch 61] Train Loss: 0.00171, Train Acc: 1.0000, Val Loss: 0.04155, Val Acc: 0.9833
# [Epoch 62] Train Loss: 0.00110, Train Acc: 1.0000, Val Loss: 0.04189, Val Acc: 0.9833
# [Epoch 63] Train Loss: 0.00100, Train Acc: 1.0000, Val Loss: 0.04214, Val Acc: 0.9778
# [Epoch 64] Train Loss: 0.00119, Train Acc: 1.0000, Val Loss: 0.04227, Val Acc: 0.9778
# [Epoch 65] Train Loss: 0.00104, Train Acc: 1.0000, Val Loss: 0.04243, Val Acc: 0.9778
# [Epoch 66] Train Loss: 0.00155, Train Acc: 1.0000, Val Loss: 0.04253, Val Acc: 0.9778
# [Epoch 67] Train Loss: 0.00120, Train Acc: 1.0000, Val Loss: 0.04266, Val Acc: 0.9778
# [Epoch 68] Train Loss: 0.00177, Train Acc: 1.0000, Val Loss: 0.04276, Val Acc: 0.9778
# [Epoch 69] Train Loss: 0.00178, Train Acc: 1.0000, Val Loss: 0.04291, Val Acc: 0.9778
# [Epoch 70] Train Loss: 0.00140, Train Acc: 1.0000, Val Loss: 0.04295, Val Acc: 0.9778
# [Epoch 71] Train Loss: 0.00116, Train Acc: 1.0000, Val Loss: 0.04299, Val Acc: 0.9778
# [Epoch 72] Train Loss: 0.00181, Train Acc: 1.0000, Val Loss: 0.04301, Val Acc: 0.9778
# [Epoch 73] Train Loss: 0.00114, Train Acc: 1.0000, Val Loss: 0.04299, Val Acc: 0.9778
# [Epoch 74] Train Loss: 0.00164, Train Acc: 1.0000, Val Loss: 0.04296, Val Acc: 0.9778
# [Epoch 75] Train Loss: 0.00139, Train Acc: 1.0000, Val Loss: 0.04293, Val Acc: 0.9778
# [Epoch 76] Train Loss: 0.00122, Train Acc: 1.0000, Val Loss: 0.04291, Val Acc: 0.9778
# [Epoch 77] Train Loss: 0.00112, Train Acc: 1.0000, Val Loss: 0.04288, Val Acc: 0.9778
# Early stopping at epoch 77
# Final model saved with validation loss: 0.04052

# %% [markdown]
# ### 6.2 Train/Validation accuracy and loss

# %%
legend = ['Train', 'Validation']

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history['train_loss'], label=legend[0])
plt.plot(history['val_loss'], label=legend[1])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.title('Loss over Epochs')

plt.subplot(1, 2, 2)
plt.plot(history['train_acc'], label=legend[0])
plt.plot(history['val_acc'], label=legend[1])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Accuracy over Epochs')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Evaluate the model

# %% [markdown]
# ### 7.1 Classify testdata using model

# %%
test_dataset = datasets.ImageFolder(root=test_data_path, transform=val_transform)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

final_model.eval()
all_preds = []
all_labels = []
all_images = []
all_probs = []
class_labels = ['Late Blight', 'Early Blight', 'Healthy']

selected_indices = best_features == 1

with torch.no_grad():
    for data, labels in test_loader:
        data, labels = data.to(device), labels.to(device)

        features = alexnet.features(data).view(data.size(0), -1)

        selected_features = features[:, selected_indices]

        outputs = final_model(selected_features)
        probabilities = torch.softmax(outputs, dim=1)
        _, predicted = torch.max(outputs, 1)

        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_images.extend(data.cpu())
        all_probs.extend(probabilities.cpu().numpy())

correct_classifications = sum(np.array(all_preds) == np.array(all_labels))
incorrect_classifications = len(all_labels) - correct_classifications

print(f'Correctly classified: {correct_classifications}')
print(f'Incorrectly classified: {incorrect_classifications}')
# Out:
# Correctly classified: 296
# Incorrectly classified: 4

# %% [markdown]
# ### 7.2 Show confusion matrix of results
#
# Explanation of the highlighted cells:
# - Red rectangles: These cells represent cases where the illness is mistakenly classified as healthy. These cells have to be zero.
# - Yellow rectangle: This cell represents cases where the severity of the illness is underestimated.
# - Green rectangles: These are correct classifications.
# - Other cells: These represent overestimated illness severity, which is less critical than underestimating.

# %%
cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(8, 6))
ax = sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
ax.xaxis.set_label_position('top')
ax.xaxis.tick_top()
highlight_cells = [(0, 2), (0, 1), (1, 2), (0, 0), (1, 1), (2, 2)]

for (i, j) in highlight_cells:
    trans = mtransforms.offset_copy(ax.transData, fig=ax.figure, x=+12.5, y=-12.5, units='points')
    if (i, j) == (0, 1):
        color = 'yellow'
    elif (i, j) in [(0, 2), (1, 2)]:
        color = 'red'
    else:
        color = 'green'

    ax.add_patch(Rectangle((j, i), 0.8, 0.8, fill=False, edgecolor=color, lw=3, transform=trans))

plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# ### 7.3 Define helper functions

# %%
def imshow(img):
    img = img / 2 + 0.5
    img = np.clip(img, 0, 1)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')

def plot_probabilities(probs, class_labels, true_label_index, pred_label_index):
    bar_positions = np.arange(len(class_labels))  # X positions for bars
    probs_true = np.zeros_like(probs)
    probs_true[true_label_index] = 1  # Set true label to 1 for green bar

    plt.bar(bar_positions - 0.15, probs, width=0.3, color='blue', label='Predicted')

    plt.bar(bar_positions + 0.15, probs_true, width=0.3, color='green', label='True')

    plt.xticks(bar_positions, class_labels, fontsize=9)

    for i, (x, prob) in enumerate(zip(bar_positions, probs)):
        plt.text(x - 0.15, prob + 0.02, f'{prob:.2f}', ha='center', fontsize=6)

    plt.text(bar_positions[true_label_index] + 0.15, 1.02, '1.00', ha='center', fontsize=6)

    plt.ylim(0, 1.1)
    plt.ylabel('Probability')
    plt.tight_layout()

# %% [markdown]
# ### 7.4 Show 9 correctly classified examples

# %%
plt.figure(figsize=(15, 10))
num_samples_per_class = 3
samples_collected = {class_name: 0 for class_name in class_labels}

for i, (img, true_label, pred_label, prob) in enumerate(zip(all_images, all_labels, all_preds, all_probs)):
    true_class_name = class_labels[true_label]
    pred_class_name = class_labels[pred_label]

    if true_label == pred_label and samples_collected[true_class_name] < num_samples_per_class:
        samples_collected[true_class_name] += 1
        plt.subplot(len(class_labels), num_samples_per_class * 2, samples_collected[true_class_name] * 2 - 1 + num_samples_per_class * 2 * true_label)
        imshow(img)
        plt.subplot(len(class_labels), num_samples_per_class * 2, samples_collected[true_class_name] * 2 + num_samples_per_class * 2 * true_label)
        plot_probabilities(prob, class_labels, true_label, pred_label)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.4 Show all misclassified images

# %%
misclassified_images = [(img, true_label, pred_label, prob) for img, true_label, pred_label, prob in zip(all_images, all_labels, all_preds, all_probs) if true_label != pred_label]
num_misclassified = len(misclassified_images)

max_misclassified = 99
num_rows = min(33, (num_misclassified + 2) // 3)

plt.figure(figsize=(20, 3 * num_rows))

for i, (img, true_label, pred_label, prob) in enumerate(misclassified_images[:max_misclassified]):
    plt.subplot(num_rows, 6, i * 2 + 1)
    imshow(img)
    plt.title(f'True: {class_labels[true_label]}\nPred: {class_labels[pred_label]}', fontsize=8)
    plt.subplot(num_rows, 6, i * 2 + 2)
    plot_probabilities(prob, class_labels, true_label, pred_label)

plt.tight_layout()
plt.show()
