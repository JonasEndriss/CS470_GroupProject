# %% [markdown]
# # MLP for the Proposal Video

# %% [markdown]
# ## Improvement Ideas
#  - Penalize false positives more heavily using the Loss
#  - Create bigger Dataset
#  - Include the algorithms introduced in the Paper
#  - Possibly change to CNN
#
# ## Current Problems
#  - To many ill as healthy classified, especcialy early blight
#  - To confident in wrong predictions

# %% [markdown]
# ## 1. Import the required libraries

# %%
# !pip install torchsummary
# !pip install kagglehub


import os
import time
import zipfile
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Rectangle
from matplotlib import transforms as mtransforms

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import models, datasets, transforms
from torchsummary import summary
from sklearn.metrics import confusion_matrix

import kagglehub
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (1.5.1)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (0.3.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from kagglehub) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub) (4.66.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub) (2024.8.30)

# %% [markdown]
# ## 2. Set model parameters

# %%
num_classes = 3

# Define the batch size (16 or 32 reccomended)
batch_size = 16

# Define the size the images get resized to (64 reccomended)
image_size = 64

# Number of epochs the trainig runs (150 reccomended)
number_of_epochs = 200

# Number of epochs without improvement of loss till the training get terminated early (20 reccomended)
early_stop_patience = 20

# If the dataset should be taken from the zip file (false reccomended (then the dataset gets downloaded))
dataset_as_zip = False

# Path of the zip file (only needed if dataset_as_zip = True)
zip_path = "../data/potato_blight.zip"

# Path where the best model should be saved to
best_model_path = '../content/best_model/best_model.pth'
if not os.path.exists(os.path.dirname(best_model_path)):
    os.makedirs(os.path.dirname(best_model_path))

# %% [markdown]
# ## 3. Get the dataset

# %% [markdown]
# ### 3.1 Import the dataset

# %%
if not dataset_as_zip:

    path = kagglehub.dataset_download("muhammadardiputra/potato-leaf-disease-dataset")

else:

    if not os.path.exists(zip_path):
        raise FileNotFoundError(f"The data expected at '{zip_path}' was not found.")

    path = "../.extracted_data"

    if not os.path.exists(path):
        os.makedirs(path)

    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(path)

train_data_path = os.path.join(path + "/Potato", "Train")
test_data_path = os.path.join(path + "/Potato", "Test")
valid_data_path = os.path.join(path + "/Potato", "Valid")

# %% [markdown]
# ### 3.2 Transform and argument the dataset

# %%
alexnet = models.alexnet(pretrained=True)
# Map to the right number of classes
alexnet.classifier[6] = nn.Linear(4096, num_classes)

train_transform = transforms.Compose([
    transforms.RandomApply([transforms.Grayscale(num_output_channels=3)], p=0.5),
    transforms.Resize((image_size, image_size)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(root=train_data_path, transform=train_transform)
val_dataset = datasets.ImageFolder(root=valid_data_path, transform=val_transform)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# ### 3.3 Load the data into batches

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

for batch_idx, (data, target) in enumerate(train_loader):
    print(f'Batch {batch_idx + 1}:')
    print('Data shape:', data.shape)
    print('Target shape:', target.shape)

mean_image = torch.mean(torch.cat([data for data, _ in train_loader], dim=0), dim=0).numpy()

print('Mean image shape:', mean_image.shape)
# Out:
# Batch 1:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 2:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 3:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 4:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 5:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 6:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 7:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 8:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 9:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 10:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 11:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 12:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 13:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 14:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 15:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 16:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 17:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 18:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 19:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 20:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 21:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 22:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 23:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 24:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 25:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 26:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 27:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 28:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 29:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 30:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 31:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 32:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 33:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 34:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 35:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 36:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 37:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 38:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 39:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 40:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 41:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 42:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 43:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 44:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 45:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 46:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 47:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 48:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 49:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 50:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 51:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 52:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 53:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 54:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 55:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 56:
# Data shape: torch.Size([16, 3, 64, 64])
# Target shape: torch.Size([16])
# Batch 57:
# Data shape: torch.Size([4, 3, 64, 64])
# Target shape: torch.Size([4])
# Mean image shape: (3, 64, 64)

# %% [markdown]
# ## 4. Define the model

# %%
class MLP(nn.Module):

    def __init__(self):
        super(MLP, self).__init__()

        self.fc1 = nn.Linear(3 * image_size * image_size, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 3)

        self.dropout = nn.Dropout(0.6)

    def forward(self, x):

        x = x.view(x.size(0), -1)

        x = F.relu(self.fc1(x))
        x = self.dropout(x)

        x = F.relu(self.fc2(x))
        x = self.dropout(x)

        x = F.relu(self.fc3(x))

        x = self.fc4(x)
        return F.log_softmax(x, dim=1)

# create a CNN object
#net = MLP()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('Device:', device)
alexnet.to(device)

num_params = sum(p.numel() for p in alexnet.parameters() if p.requires_grad)
print("Number of trainable parameters:", num_params)

summary(alexnet, (3, image_size, image_size))
# Out:
# Device: cuda:0
# Number of trainable parameters: 57016131
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 15, 15]          23,296
#               ReLU-2           [-1, 64, 15, 15]               0
#          MaxPool2d-3             [-1, 64, 7, 7]               0
#             Conv2d-4            [-1, 192, 7, 7]         307,392
#               ReLU-5            [-1, 192, 7, 7]               0
#          MaxPool2d-6            [-1, 192, 3, 3]               0
#             Conv2d-7            [-1, 384, 3, 3]         663,936
#               ReLU-8            [-1, 384, 3, 3]               0
#             Conv2d-9            [-1, 256, 3, 3]         884,992
#              ReLU-10            [-1, 256, 3, 3]               0
#            Conv2d-11            [-1, 256, 3, 3]         590,080
#              ReLU-12            [-1, 256, 3, 3]               0
#         MaxPool2d-13            [-1, 256, 1, 1]               0
# AdaptiveAvgPool2d-14            [-1, 256, 6, 6]               0
#           Dropout-15                 [-1, 9216]               0
#            Linear-16                 [-1, 4096]      37,752,832
#              ReLU-17                 [-1, 4096]               0
#           Dropout-18                 [-1, 4096]               0
#            Linear-19                 [-1, 4096]      16,781,312
#              ReLU-20                 [-1, 4096]               0
#            Linear-21                    [-1, 3]          12,291
# ================================================================
# Total params: 57,016,131
# Trainable params: 57,016,131
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 0.82
# Params size (MB): 217.50
# Estimated Total Size (MB): 218.37
# ----------------------------------------------------------------

# %% [markdown]
# ## 5. Train the model

# %% [markdown]
# ### 5.1 Define and run the training

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(alexnet.parameters(), lr=0.001, weight_decay=1e-4)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min',
                                                 factor=0.5,
                                                 patience=5,
                                                 min_lr=1e-6)

early_stop_counter = 0
best_val_loss = float('inf')
best_val_acc = 0.0
best_model_state = None

history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

for epoch in range(number_of_epochs):
    start_time = time.time()

    alexnet.train()
    running_loss = 0.0
    correct = 0
    count = 0

    for batch, labels in train_loader:
        batch, labels = batch.to(device), labels.to(device)
        count += len(batch)

        optimizer.zero_grad()

        outputs = alexnet(batch)
        loss = criterion(outputs, labels)
        loss.backward()

        torch.nn.utils.clip_grad_norm_(alexnet.parameters(), max_norm=2.0)

        optimizer.step()

        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        running_loss += loss.item()

    avg_train_loss = running_loss / count
    avg_train_acc = correct / count
    history['train_loss'].append(avg_train_loss)
    history['train_acc'].append(avg_train_acc)

    alexnet.eval()
    val_loss = 0.0
    correct_val = 0
    count_val = 0

    with torch.no_grad():
        for batch, labels in val_loader:
            batch, labels = batch.to(device), labels.to(device)
            count_val += len(batch)

            outputs = alexnet(batch)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs, 1)
            correct_val += (predicted == labels).sum().item()
            val_loss += loss.item()

    avg_val_loss = val_loss / count_val
    avg_val_acc = correct_val / count_val
    history['val_loss'].append(avg_val_loss)
    history['val_acc'].append(avg_val_acc)

    elapsed_time = time.time() - start_time
    print(f"[Epoch {epoch+1}] Train loss: {avg_train_loss:.5f}, Train accuracy: {avg_train_acc:.4f}, "
          f"Val loss: {avg_val_loss:.5f}, Val accuracy: {avg_val_acc:.4f}, Time: {elapsed_time:.2f}s")

    scheduler.step(avg_val_loss)

    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        best_val_acc = avg_val_acc
        early_stop_counter = 0
        best_model_state = {
            'epoch': epoch,
            'model_state_dict': alexnet.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'best_val_loss': best_val_loss,
        }
        print(f"Saved best model at epoch {epoch+1} with validation loss: {best_val_loss:.5f}")
    else:
        early_stop_counter += 1
        if early_stop_counter >= early_stop_patience:
            print(f"Early stopping at epoch {epoch+1}. No improvement in validation loss for {early_stop_patience} epochs.")
            break

torch.save(best_model_state, best_model_path)
print(f"Best model saved with validation loss: {best_val_loss:.5f}, accuracy: {best_val_acc:.4f}")
alexnet.load_state_dict(best_model_state['model_state_dict'])
optimizer.load_state_dict(best_model_state['optimizer_state_dict'])
alexnet.to(device)
# Out:
# [Epoch 1] Train loss: 0.08115, Train accuracy: 0.4111, Val loss: 0.05802, Val accuracy: 0.5867, Time: 2.92s
# Saved best model at epoch 1 with validation loss: 0.05802
# [Epoch 2] Train loss: 0.06826, Train accuracy: 0.6056, Val loss: 0.05317, Val accuracy: 0.6433, Time: 2.89s
# Saved best model at epoch 2 with validation loss: 0.05317
# [Epoch 3] Train loss: 0.04908, Train accuracy: 0.7489, Val loss: 0.02339, Val accuracy: 0.8767, Time: 3.75s
# Saved best model at epoch 3 with validation loss: 0.02339
# [Epoch 4] Train loss: 0.04149, Train accuracy: 0.8067, Val loss: 0.03346, Val accuracy: 0.7867, Time: 3.69s
# [Epoch 5] Train loss: 0.03958, Train accuracy: 0.8222, Val loss: 0.14576, Val accuracy: 0.7267, Time: 2.73s
# [Epoch 6] Train loss: 0.04721, Train accuracy: 0.8300, Val loss: 0.01709, Val accuracy: 0.8900, Time: 2.72s
# Saved best model at epoch 6 with validation loss: 0.01709
# [Epoch 7] Train loss: 0.02790, Train accuracy: 0.8656, Val loss: 0.01450, Val accuracy: 0.9200, Time: 3.80s
# Saved best model at epoch 7 with validation loss: 0.01450
# [Epoch 8] Train loss: 0.02825, Train accuracy: 0.8922, Val loss: 0.02100, Val accuracy: 0.9233, Time: 3.09s
# [Epoch 9] Train loss: 0.02468, Train accuracy: 0.8889, Val loss: 0.02111, Val accuracy: 0.9167, Time: 3.34s
# [Epoch 10] Train loss: 0.03066, Train accuracy: 0.8733, Val loss: 0.01239, Val accuracy: 0.9300, Time: 2.84s
# Saved best model at epoch 10 with validation loss: 0.01239
# [Epoch 11] Train loss: 0.03181, Train accuracy: 0.9000, Val loss: 0.01686, Val accuracy: 0.9100, Time: 4.37s
# [Epoch 12] Train loss: 0.02315, Train accuracy: 0.9033, Val loss: 0.04337, Val accuracy: 0.8700, Time: 3.81s
# [Epoch 13] Train loss: 0.02664, Train accuracy: 0.9133, Val loss: 0.01889, Val accuracy: 0.9533, Time: 2.69s
# [Epoch 14] Train loss: 0.02243, Train accuracy: 0.9189, Val loss: 0.01175, Val accuracy: 0.9267, Time: 2.71s
# Saved best model at epoch 14 with validation loss: 0.01175
# [Epoch 15] Train loss: 0.03030, Train accuracy: 0.9056, Val loss: 0.02100, Val accuracy: 0.9200, Time: 3.48s
# [Epoch 16] Train loss: 0.01828, Train accuracy: 0.9078, Val loss: 0.01672, Val accuracy: 0.9300, Time: 3.36s
# [Epoch 17] Train loss: 0.02225, Train accuracy: 0.9111, Val loss: 0.01497, Val accuracy: 0.9500, Time: 2.74s
# [Epoch 18] Train loss: 0.01856, Train accuracy: 0.9367, Val loss: 0.04478, Val accuracy: 0.8867, Time: 2.75s
# [Epoch 19] Train loss: 0.02555, Train accuracy: 0.9044, Val loss: 0.01524, Val accuracy: 0.9433, Time: 2.75s
# [Epoch 20] Train loss: 0.01976, Train accuracy: 0.9256, Val loss: 0.02271, Val accuracy: 0.9233, Time: 3.85s
# [Epoch 21] Train loss: 0.01420, Train accuracy: 0.9333, Val loss: 0.01258, Val accuracy: 0.9400, Time: 2.72s
# [Epoch 22] Train loss: 0.01261, Train accuracy: 0.9489, Val loss: 0.02219, Val accuracy: 0.9200, Time: 2.72s
# [Epoch 23] Train loss: 0.01355, Train accuracy: 0.9522, Val loss: 0.01834, Val accuracy: 0.9467, Time: 2.74s
# [Epoch 24] Train loss: 0.01200, Train accuracy: 0.9600, Val loss: 0.02284, Val accuracy: 0.9467, Time: 3.31s
# [Epoch 25] Train loss: 0.01036, Train accuracy: 0.9644, Val loss: 0.02339, Val accuracy: 0.9367, Time: 3.67s
# [Epoch 26] Train loss: 0.00789, Train accuracy: 0.9667, Val loss: 0.01509, Val accuracy: 0.9533, Time: 2.71s
# [Epoch 27] Train loss: 0.00653, Train accuracy: 0.9756, Val loss: 0.01413, Val accuracy: 0.9567, Time: 2.71s
# [Epoch 28] Train loss: 0.00561, Train accuracy: 0.9744, Val loss: 0.01205, Val accuracy: 0.9667, Time: 2.72s
# [Epoch 29] Train loss: 0.00508, Train accuracy: 0.9811, Val loss: 0.00704, Val accuracy: 0.9767, Time: 3.49s
# Saved best model at epoch 29 with validation loss: 0.00704
# [Epoch 30] Train loss: 0.00407, Train accuracy: 0.9800, Val loss: 0.01137, Val accuracy: 0.9733, Time: 3.75s
# [Epoch 31] Train loss: 0.00466, Train accuracy: 0.9789, Val loss: 0.01089, Val accuracy: 0.9533, Time: 2.80s
# [Epoch 32] Train loss: 0.00506, Train accuracy: 0.9778, Val loss: 0.01814, Val accuracy: 0.9433, Time: 2.68s
# [Epoch 33] Train loss: 0.00561, Train accuracy: 0.9778, Val loss: 0.01436, Val accuracy: 0.9433, Time: 2.68s
# [Epoch 34] Train loss: 0.00427, Train accuracy: 0.9767, Val loss: 0.01886, Val accuracy: 0.9533, Time: 3.60s
# [Epoch 35] Train loss: 0.00766, Train accuracy: 0.9767, Val loss: 0.01154, Val accuracy: 0.9600, Time: 2.99s
# [Epoch 36] Train loss: 0.00337, Train accuracy: 0.9833, Val loss: 0.01083, Val accuracy: 0.9633, Time: 2.76s
# [Epoch 37] Train loss: 0.00256, Train accuracy: 0.9878, Val loss: 0.01494, Val accuracy: 0.9600, Time: 2.72s
# [Epoch 38] Train loss: 0.00397, Train accuracy: 0.9844, Val loss: 0.01456, Val accuracy: 0.9533, Time: 3.05s
# [Epoch 39] Train loss: 0.00314, Train accuracy: 0.9900, Val loss: 0.01312, Val accuracy: 0.9700, Time: 3.97s
# [Epoch 40] Train loss: 0.00244, Train accuracy: 0.9878, Val loss: 0.01540, Val accuracy: 0.9633, Time: 2.73s
# [Epoch 41] Train loss: 0.00209, Train accuracy: 0.9889, Val loss: 0.01523, Val accuracy: 0.9600, Time: 2.75s
# [Epoch 42] Train loss: 0.00239, Train accuracy: 0.9889, Val loss: 0.01509, Val accuracy: 0.9600, Time: 2.76s
# [Epoch 43] Train loss: 0.00127, Train accuracy: 0.9944, Val loss: 0.01392, Val accuracy: 0.9667, Time: 3.28s
# [Epoch 44] Train loss: 0.00080, Train accuracy: 0.9944, Val loss: 0.01781, Val accuracy: 0.9600, Time: 3.93s
# [Epoch 45] Train loss: 0.00165, Train accuracy: 0.9922, Val loss: 0.01553, Val accuracy: 0.9667, Time: 2.67s
# [Epoch 46] Train loss: 0.00243, Train accuracy: 0.9922, Val loss: 0.01482, Val accuracy: 0.9667, Time: 2.73s
# [Epoch 47] Train loss: 0.00088, Train accuracy: 0.9956, Val loss: 0.01577, Val accuracy: 0.9633, Time: 2.72s
# [Epoch 48] Train loss: 0.00078, Train accuracy: 0.9956, Val loss: 0.01510, Val accuracy: 0.9667, Time: 4.13s
# [Epoch 49] Train loss: 0.00166, Train accuracy: 0.9933, Val loss: 0.01486, Val accuracy: 0.9733, Time: 2.90s
# Early stopping at epoch 49. No improvement in validation loss for 20 epochs.
# Best model saved with validation loss: 0.00704, accuracy: 0.9767
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# ### 5.2 Train/Validation accuracy and loss

# %%
legend = ['Train', 'Validation']

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history['train_loss'], label=legend[0])
plt.plot(history['val_loss'], label=legend[1])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.title('Loss over Epochs')

plt.subplot(1, 2, 2)
plt.plot(history['train_acc'], label=legend[0])
plt.plot(history['val_acc'], label=legend[1])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Accuracy over Epochs')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Evaluate the model

# %% [markdown]
# ### 6.1 Classify testdata using model

# %%
test_dataset = datasets.ImageFolder(root=test_data_path, transform=val_transform)

test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=16, shuffle=False)

alexnet.eval()

all_preds = []
all_labels = []
all_images = []
all_probs = []
class_labels = ['Late Blight', 'Early Blight', 'Healthy']

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = alexnet(images)
        probabilities = F.softmax(outputs, dim=1)
        _, predicted = torch.max(outputs, 1)

        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_images.extend(images.cpu())
        all_probs.extend(probabilities.cpu().numpy())

correct_classifications = sum(np.array(all_preds) == np.array(all_labels))
incorrect_classifications = len(all_labels) - correct_classifications

print(f'Correctly classified: {correct_classifications}')
print(f'Incorrectly classified: {incorrect_classifications}')
# Out:
# Correctly classified: 290
# Incorrectly classified: 10

# %% [markdown]
# ### 6.2 Show confusion matrix of results
#
# Explanation of the highlighted cells:
# - Red rectangles: These cells represent cases where the illness is mistakenly classified as healthy. These cells have to be zero.
# - Yellow rectangle: This cell represents cases where the severity of the illness is underestimated.
# - Green rectangles: These are correct classifications.
# - Other cells: These represent overestimated illness severity, which is less critical than underestimating.

# %%
cm = confusion_matrix(all_labels, all_preds)

plt.figure(figsize=(8, 6))
ax = sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
ax.xaxis.set_label_position('top')
ax.xaxis.tick_top()
highlight_cells = [(0, 2), (0, 1), (1, 2), (0, 0), (1, 1), (2, 2)]

for (i, j) in highlight_cells:
    trans = mtransforms.offset_copy(ax.transData, fig=ax.figure, x=+12.5, y=-12.5, units='points')
    if (i, j) == (0, 1):
        color = 'yellow'
    elif (i, j) in [(0, 2), (1, 2)]:
        color = 'red'
    else:
        color = 'green'

    ax.add_patch(Rectangle((j, i), 0.8, 0.8, fill=False, edgecolor=color, lw=3, transform=trans))

plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# ### 6.3 Define helper functions

# %%
def imshow(img):
    img = img / 2 + 0.5
    img = np.clip(img, 0, 1)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')

def plot_probabilities(probs, class_labels, true_label_index, pred_label_index):
    bar_positions = np.arange(len(class_labels))  # X positions for bars
    probs_true = np.zeros_like(probs)
    probs_true[true_label_index] = 1  # Set true label to 1 for green bar

    plt.bar(bar_positions - 0.15, probs, width=0.3, color='blue', label='Predicted')

    plt.bar(bar_positions + 0.15, probs_true, width=0.3, color='green', label='True')

    plt.xticks(bar_positions, class_labels, fontsize=9)

    for i, (x, prob) in enumerate(zip(bar_positions, probs)):
        plt.text(x - 0.15, prob + 0.02, f'{prob:.2f}', ha='center', fontsize=6)

    plt.text(bar_positions[true_label_index] + 0.15, 1.02, '1.00', ha='center', fontsize=6)

    plt.ylim(0, 1.1)
    plt.ylabel('Probability')
    plt.tight_layout()

# %% [markdown]
# ### 6.4 Show 9 correctly classified examples

# %%
plt.figure(figsize=(15, 10))
num_samples_per_class = 3
samples_collected = {class_name: 0 for class_name in class_labels}

for i, (img, true_label, pred_label, prob) in enumerate(zip(all_images, all_labels, all_preds, all_probs)):
    true_class_name = class_labels[true_label]
    pred_class_name = class_labels[pred_label]

    if true_label == pred_label and samples_collected[true_class_name] < num_samples_per_class:
        samples_collected[true_class_name] += 1
        plt.subplot(len(class_labels), num_samples_per_class * 2, samples_collected[true_class_name] * 2 - 1 + num_samples_per_class * 2 * true_label)
        imshow(img)
        plt.subplot(len(class_labels), num_samples_per_class * 2, samples_collected[true_class_name] * 2 + num_samples_per_class * 2 * true_label)
        plot_probabilities(prob, class_labels, true_label, pred_label)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.4 Show all misclassified images

# %%
misclassified_images = [(img, true_label, pred_label, prob) for img, true_label, pred_label, prob in zip(all_images, all_labels, all_preds, all_probs) if true_label != pred_label]
num_misclassified = len(misclassified_images)

max_misclassified = 99
num_rows = min(33, (num_misclassified + 2) // 3)

plt.figure(figsize=(20, 3 * num_rows))

for i, (img, true_label, pred_label, prob) in enumerate(misclassified_images[:max_misclassified]):
    plt.subplot(num_rows, 6, i * 2 + 1)
    imshow(img)
    plt.title(f'True: {class_labels[true_label]}\nPred: {class_labels[pred_label]}', fontsize=8)
    plt.subplot(num_rows, 6, i * 2 + 2)
    plot_probabilities(prob, class_labels, true_label, pred_label)

plt.tight_layout()
plt.show()
